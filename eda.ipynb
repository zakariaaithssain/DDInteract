# %% [markdown]
# DDInter 2.0 Class Distribution

# %%
import pandas as pd

df = pd.read_csv("data/chemical_ddi.csv")
print("data shape: ", df.shape)
print("severity class count:\n ", df["severity"].value_counts())
print("severity class pourcentage:\n ", df["severity"].value_counts() / len(df) * 100)
# Out:
# data shape:  (109441, 6)
# severity class count:
#   severity
# Moderate    82013
# Major       21373
# Minor        6055
# Name: count, dtype: int64
# severity class pourcentage:
#   severity
# Moderate    74.938094
# Major       19.529244
# Minor        5.532661
# Name: count, dtype: float64
